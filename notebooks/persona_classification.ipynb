# %% [markdown]
# # Semantic Persona Classification of USS Reviews
#
# ## Using Sentence Transformers and Cosine Similarity
#
# ### Objective:
# To develop and evaluate a semantic-based machine learning model that classifies Universal Studios Singapore (USS) user reviews into six distinct visitor personas — **Families**, **Thrill Seekers**, **International Tourists**, **Budget Conscious**, **Premium Visitors**, and **Experience Focused** — using sentence transformer embeddings and cosine similarity matching.
#
# ### Dataset:
# Google Reviews collected for Universal Studios Singapore, including textual reviews, star ratings, and temporal metadata spanning multiple years.
#
# ### Methodology:
# - **Data Loading**: Using pre-processed USS review dataset (cleaned in previous analysis)
# - **Semantic Embeddings**: Using BAAI/bge-large-en-v1.5 sentence transformer model with GPU acceleration
# - **Persona Definition**: Six detailed semantic descriptions with positive and negative indicators
# - **Batch Processing**: Efficient embedding generation with batch size optimization (512 reviews/batch)
# - **Classification**: Cosine similarity calculation between review embeddings and persona embeddings
# - **Enhanced Analysis**: Primary and secondary persona identification with confidence gap calculation
# - **Results Export**: Dual format output (CSV + Parquet) with full similarity matrices
#
# ### Evaluation Metrics:
# - **Classification Distribution**: Persona percentage breakdown and counts
# - **Confidence Statistics**: Mean, median, min, max confidence scores per persona
# - **Mixed Persona Analysis**: Detection of users with confidence gaps < 0.05
# - **Uncertainty Detection**: Reviews with confidence gaps < 0.1 requiring validation
# - **Cross-Persona Patterns**: Most common primary-secondary persona combinations
# - **Star Rating Correlation**: Validation against user satisfaction scores
# - **High-Confidence Sampling**: Top examples per persona for quality assessment

# %%
# Business-Oriented Review Analysis for Universal Studios Singapore
# Focus: Monthly operational issue tracking + visitor persona analysis

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# Set up plotting style
plt.style.use('default')
sns.set_palette("husl")
plt.rcParams['figure.figsize'] = (12, 8)

print("🎯 Business-Oriented USS Review Analysis")
print("=" * 50)

# Define project paths
project_root = Path('.').resolve().parent
data_path = project_root / 'data' / 'processed'

print(f"Loading data from: {data_path}")

# Load the cleaned dataset
df = pd.read_csv(data_path / 'USS_Reviews_Silver_cleaned_l2.csv')

# # Basic preprocessing (from previous analysis)
# df['review_length'] = df['review'].str.len()
# df['publishedAtDate'] = pd.to_datetime(df['publishedAtDate'])



print(f"Dataset prepared: {len(df):,} reviews")
print(f"Date range: {df['publishedAtDate'].min()} to {df['publishedAtDate'].max()}")
print(f"Star rating distribution:")
print(df['stars'].value_counts().sort_index())
# Out:
# 🎯 Business-Oriented USS Review Analysis
# ==================================================
# Loading data from: C:\Users\nshan\Desktop\SMU\MITB\CS605\project\CS605-NLP-Project\data\processed
# Dataset prepared: 24,021 reviews
# Date range: 2018-07-29 to 2025-05-23
# Star rating distribution:
# stars
# 1     1311
# 2      796
# 3     1982
# 4     4851
# 5    15081
# Name: count, dtype: int64

# %%
# Phase 2 continued: Pure semantic vector matching

# Install and import required libraries
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import torch

# Check GPU availability
print(f"CUDA available: {torch.cuda.is_available()}")
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}")
# Out:
# CUDA available: True
# Using device: cuda

# %%
# Load sentence transformer model
model_name = 'BAAI/bge-large-en-v1.5'  # Good balance of speed and quality
print(f"\nLoading model: {model_name}")
sentence_model = SentenceTransformer(model_name, device=device)
print("Model loaded successfully!")

# Simplified persona definitions (pure descriptions for semantic matching)
persona_descriptions = {
    'families': """Parents with young children and teenagers. Key phrases: "with kids", "children", "family", 
    "parents", "suitable for kids", "child-friendly", "age-appropriate", "family bonding", "stroller", 
    "educational for children", "traveling with family", "good for kids and parents".
    
    NEGATIVE INDICATORS: Does NOT mention solo travel, adrenaline, scary rides, first-time Singapore visit, 
    price complaints, express passes, queue problems, staff issues, maintenance problems.""",
    

    'thrill_seekers': """Adrenaline junkies focused on intense rides. Key phrases: "adrenaline", "scary", 
    "intense", "thrilling", "roller coaster", "extreme", "heart-pounding", "not for faint hearted", 
    "test of courage", "fear factor", "exciting and tense", "adrenaline rush", "challenging rides".
    
    NEGATIVE INDICATORS: Does NOT mention family activities, children, Singapore tourism, cost concerns, 
    VIP services, operational complaints, staff problems, maintenance issues.""",

    'international_tourists': """Foreign visitors to Singapore discussing travel planning. Key phrases: 
    "first time in Singapore", "visiting Singapore", "must visit", "bucket list", "travel to Singapore", 
    "Singapore attractions", "tourist destination", "once in lifetime", "Singapore itinerary", "foreign tourists".
    
    NEGATIVE INDICATORS: Does NOT mention family activities, adrenaline rides, price complaints, 
    premium services, operational issues, staff problems, local resident experiences.""",
    
    'budget_conscious': """Visitors angry about high costs and poor value. Key phrases: "expensive", 
    "overpriced", "not worth the money", "waste of money", "too expensive", "jaw-breaking expensive", 
    "insane prices", "poor value", "financially disappointed", "ripped off", "budget constraints".
    
    NEGATIVE INDICATORS: Does NOT mention family fun, thrilling experiences, Singapore tourism, 
    premium services, positive service experiences, adrenaline activities.""",
    
    'premium_visitors': """Users who bought or recommend paid upgrades. Key phrases: "express pass", 
    "VIP", "fast track", "skip the line", "priority access", "bought express", "recommend express", 
    "worth buying express", "VIP experience", "premium service", "exclusive access", "personal guide".
    
    NEGATIVE INDICATORS: Does NOT mention cost complaints, family-specific needs, adrenaline seeking, 
    Singapore travel planning, operational complaints, basic ticket experiences.""",
    
    'experience_focused': """Visitors complaining about operations and service quality. Key phrases: 
    "long queues", "waiting time", "staff attitude", "poor service", "maintenance issues", "attraction closed", 
    "crowd management", "facility problems", "operational issues", "park management", "service quality".
    
    NEGATIVE INDICATORS: Does NOT mention price concerns, family activities, thrill experiences, 
    Singapore tourism, premium services, positive experiences."""
}

print(f"\nGenerating embeddings for {len(persona_descriptions)} personas...")

# Generate embeddings for persona descriptions
persona_embeddings = {}
for persona, description in persona_descriptions.items():
    embedding = sentence_model.encode([description])
    persona_embeddings[persona] = embedding[0]
    print(f"✓ {persona}: embedding shape {embedding.shape}")

print("\nPersona embeddings ready for classification!")
# Out:
# Loading model: BAAI/bge-large-en-v1.5
# Model loaded successfully!
#
# Generating embeddings for 6 personas...
# ✓ families: embedding shape (1, 1024)
# ✓ thrill_seekers: embedding shape (1, 1024)
# ✓ international_tourists: embedding shape (1, 1024)
# ✓ budget_conscious: embedding shape (1, 1024)
# ✓ premium_visitors: embedding shape (1, 1024)
# ✓ experience_focused: embedding shape (1, 1024)
#
# Persona embeddings ready for classification!

# %%
# Phase 3: Batch review classification

import time
from tqdm import tqdm

print("Starting batch review classification...")
print("=" * 50)

# Prepare review data
reviews_list = df['review'].tolist()
total_reviews = len(reviews_list)

print(f"Total reviews to classify: {total_reviews:,}")
print(f"Batch processing on {device.upper()}")

# Set batch size for efficient GPU processing
batch_size = 512  # Adjust based on GPU memory
print(f"Batch size: {batch_size}")

# Generate embeddings for all reviews in batches
print("\nGenerating review embeddings...")
start_time = time.time()

all_review_embeddings = []
for i in tqdm(range(0, total_reviews, batch_size), desc="Processing batches"):
    batch = reviews_list[i:i + batch_size]
    batch_embeddings = sentence_model.encode(batch, device=device, show_progress_bar=False)
    all_review_embeddings.extend(batch_embeddings)

review_embeddings = np.array(all_review_embeddings)
end_time = time.time()

print(f"\n✓ Generated embeddings for {total_reviews:,} reviews")
print(f"Processing time: {end_time - start_time:.2f} seconds")
print(f"Embedding matrix shape: {review_embeddings.shape}")
print(f"Speed: {total_reviews / (end_time - start_time):.0f} reviews/second")
# Out:
# Starting batch review classification...
# ==================================================
# Total reviews to classify: 24,021
# Batch processing on CUDA
# Batch size: 512
#
# Generating review embeddings...
# Processing batches: 100%|██████████| 47/47 [04:15<00:00,  5.43s/it]
# ✓ Generated embeddings for 24,021 reviews
# Processing time: 255.28 seconds
# Embedding matrix shape: (24021, 1024)
# Speed: 94 reviews/second

# %%
# Phase 4: Cosine similarity calculation and classification

print("Computing persona similarities and classifications...")
print("=" * 50)

# Convert persona embeddings to numpy array for efficient computation
persona_names = list(persona_embeddings.keys())
persona_matrix = np.array([persona_embeddings[name] for name in persona_names])

print(f"Persona matrix shape: {persona_matrix.shape}")
print(f"Review matrix shape: {review_embeddings.shape}")

# Calculate cosine similarities between all reviews and all personas
print("\nCalculating cosine similarities...")
start_time = time.time()

# Use sklearn's efficient cosine similarity
similarity_matrix = cosine_similarity(review_embeddings, persona_matrix)

end_time = time.time()
print(f"Similarity calculation completed in {end_time - start_time:.2f} seconds")
print(f"Similarity matrix shape: {similarity_matrix.shape}")

# Classify each review to the most similar persona
print("\nClassifying reviews...")

# Get the persona with highest similarity for each review
best_persona_indices = np.argmax(similarity_matrix, axis=1)
best_similarities = np.max(similarity_matrix, axis=1)

# Create classification results
classification_results = []
for i, (persona_idx, similarity) in enumerate(zip(best_persona_indices, best_similarities)):
    classification_results.append({
        'review_index': i,
        'best_persona': persona_names[persona_idx],
        'confidence': similarity,
        'all_similarities': dict(zip(persona_names, similarity_matrix[i]))
    })

print(f"✓ Classified {len(classification_results):,} reviews")

# Quick statistics
print(f"\nClassification confidence statistics:")
print(f"Mean confidence: {np.mean(best_similarities):.3f}")
print(f"Median confidence: {np.median(best_similarities):.3f}")
print(f"Min confidence: {np.min(best_similarities):.3f}")
print(f"Max confidence: {np.max(best_similarities):.3f}")
# Out:
# Computing persona similarities and classifications...
# ==================================================
# Persona matrix shape: (6, 1024)
# Review matrix shape: (24021, 1024)
#
# Calculating cosine similarities...
# Similarity calculation completed in 0.10 seconds
# Similarity matrix shape: (24021, 6)
#
# Classifying reviews...
# ✓ Classified 24,021 reviews
#
# Classification confidence statistics:
# Mean confidence: 0.543
# Median confidence: 0.550
# Min confidence: 0.302
# Max confidence: 0.762

# %%
# Phase 5: Classification results analysis and sample inspection

print("Classification Distribution Analysis")
print("=" * 50)

# Add classification results to dataframe
df_classified = df.copy()
df_classified['predicted_persona'] = [result['best_persona'] for result in classification_results]
df_classified['confidence'] = [result['confidence'] for result in classification_results]

# 1. Overall distribution
print("1. PERSONA DISTRIBUTION:")
persona_counts = df_classified['predicted_persona'].value_counts()
persona_percentages = (persona_counts / len(df_classified) * 100).round(1)

for persona in persona_names:
    count = persona_counts.get(persona, 0)
    pct = persona_percentages.get(persona, 0)
    print(f"   {persona:20}: {count:5,} reviews ({pct:5.1f}%)")

# 2. Confidence distribution by persona
print(f"\n2. CONFIDENCE BY PERSONA:")
for persona in persona_names:
    persona_data = df_classified[df_classified['predicted_persona'] == persona]
    if len(persona_data) > 0:
        mean_conf = persona_data['confidence'].mean()
        std_conf = persona_data['confidence'].std()
        print(f"   {persona:20}: {mean_conf:.3f} ± {std_conf:.3f}")

# 3. Star rating correlation
print(f"\n3. PERSONA vs STAR RATING:")
persona_star_crosstab = pd.crosstab(df_classified['predicted_persona'], df_classified['stars'], normalize='index') * 100
print(persona_star_crosstab.round(1))

# 4. High confidence samples (top 3 per persona)
print(f"\n4. HIGH CONFIDENCE SAMPLES:")
print("=" * 60)

for persona in persona_names:
    persona_data = df_classified[df_classified['predicted_persona'] == persona]
    if len(persona_data) > 0:
        top_samples = persona_data.nlargest(8, 'confidence')
        print(f"\n{persona.upper()} (Top 8 high confidence):")
        for idx, row in top_samples.iterrows():
            print(f"   Confidence: {row['confidence']:.3f} | Stars: {row['stars']}")
            print(f"   Review: \"{row['review'][:350]}...\"")
            print()
# Out:
# Classification Distribution Analysis
# ==================================================
# 1. PERSONA DISTRIBUTION:
#    families            : 5,076 reviews ( 21.1%)
#    thrill_seekers      : 3,141 reviews ( 13.1%)
#    international_tourists: 3,649 reviews ( 15.2%)
#    budget_conscious    : 1,323 reviews (  5.5%)
#    premium_visitors    : 2,914 reviews ( 12.1%)
#    experience_focused  : 7,918 reviews ( 33.0%)
#
# 2. CONFIDENCE BY PERSONA:
#    families            : 0.519 ± 0.073
#    thrill_seekers      : 0.504 ± 0.064
#    international_tourists: 0.541 ± 0.070
#    budget_conscious    : 0.527 ± 0.074
#    premium_visitors    : 0.549 ± 0.076
#    experience_focused  : 0.575 ± 0.069
#
# 3. PERSONA vs STAR RATING:
# stars                      1    2     3     4     5
# predicted_persona
# budget_conscious        10.4  7.6  16.3  20.9  44.7
# experience_focused      13.5  7.9  16.2  26.2  36.2
# families                 0.4  0.5   3.9  19.7  75.6
# international_tourists   0.4  0.3   1.8  12.9  84.6
# premium_visitors         2.1  0.8   5.2  19.3  72.6
# thrill_seekers           0.2  0.4   2.3  14.9  82.3
#
# 4. HIGH CONFIDENCE SAMPLES:
# ============================================================
#
# FAMILIES (Top 8 high confidence):
#    Confidence: 0.723 | Stars: 5
#    Review: "Good travel with small and big kids. There are zone for teenagers and younger kids.Most importantly, they have few cozy places for adults to spend their free times with friends.eg casio and cinema and more cafe too..."
#
#    Confidence: 0.714 | Stars: 5
#    Review: "It was an amazing experience with family there. One of the best places to be visited in Singapore. The minimum age for kids to ride is 4 but few rides allow them based on their height too. Kids above 4 years are chargeable so make sure you take a ticket for them. And have FUN...."
#
#    Confidence: 0.708 | Stars: 5
#    Review: "I really like going here, the place is very INSTAGRAMable.. The kids are really happy, especially the parents.. haha it's really a kid's heaven.. I bought the entrance ticket at Traveloka, so when I got there I just showed the e-ticket to the gate officer, no need to print it, so it's more practical and no need to queue. Transportation in Singapore..."
#
#    Confidence: 0.694 | Stars: 4
#    Review: "Travel with family to Singapore..."
#
#    Confidence: 0.693 | Stars: 3
#    Review: "Very much aimed at young children, with very little for Adults, the exception being Cyclone. Tickets arent cheap but are inline with Singapore expectations. The Express (Fast Pass) tickets are worthwhile to cut queue times but at 140 they are extortionate prices. Like all of Singapore, its clean and friendly...."
#
#    Confidence: 0.692 | Stars: 5
#    Review: "A child-friendly place and suitable for traveling with family. highly recommended..."
#
#    Confidence: 0.691 | Stars: 5
#    Review: "It's amazing when i still child. With family 14 people go to singapore. We not get to inside Universal but we took around sentosa island. It's great place 4 days in singapore and i'm really happy. Bad for me because i just get some photo in there. But for recreation family is very good. I never forget that...."
#
#    Confidence: 0.691 | Stars: 5
#    Review: "A very pleasant place to visit in Singapore. Apart from theme parks, there are actually other options to visit, including aquariums and museums, which can be an option for parents who bring children aged 7 years and under...."
#
#
# THRILL_SEEKERS (Top 8 high confidence):
#    Confidence: 0.704 | Stars: 5
#    Review: "One of the top spots in Singapore, highly crowded because of its popularity, is highly recommended for adrenaline junkies. Suggestion: Spend a Lil more to save time because of the long queues, buy an express pass...."
#
#    Confidence: 0.704 | Stars: 5
#    Review: "Adrenalin rush riding the extreme rides...."
#
#    Confidence: 0.701 | Stars: 5
#    Review: "The best place to get your adrenaline spiked. The rides are amazing and thrilling. The staff is very polite and also so many souvenirs to get. If you visit Singapore, you have to visit here Love Love Love..."
#
#    Confidence: 0.697 | Stars: 5
#    Review: "One of the few places for adrenaline seekers in SG..."
#
#    Confidence: 0.695 | Stars: 4
#    Review: "The most popular theme park in south east asia I guess. They divided the park with about 5 main theme. Attractions are really interesting and great. They even tell the instructions with 2 language (English and Chinese) and wrote some with Malay too. If you're the adrenaline's junkie, they got some attractions that you will definitely need to try. A..."
#
#    Confidence: 0.680 | Stars: 5
#    Review: "Roller coaster ride. You need lot of courage and inner strength to face gravity forces in roller coaster guide. Clean toilets available...."
#
#    Confidence: 0.675 | Stars: 5
#    Review: "Universal Studios Singapore is a world class theme park. They have various rides and attractions, each with distinct themes. They have many options for non-adrenaline riders as well. Will be looking forward to visit again...."
#
#    Confidence: 0.669 | Stars: 5
#    Review: "Must visit place for the adventure seekers in singapore. There are 5-6 rides will definitely gives you chills and adrenaline rush. Transformer, The Mummy, Battelstar Gallecia Cycon & Human, Jurrasic world. These are the rides which you should not miss out...."
#
#
# INTERNATIONAL_TOURISTS (Top 8 high confidence):
#    Confidence: 0.721 | Stars: 5
#    Review: "1st timer in Singapore should include on their itenerary...."
#
#    Confidence: 0.717 | Stars: 5
#    Review: "The first time I went to Singapore was to come here. I was pleasantly surprised. It was much better than I expected. I am a tourist from Malaysia. Lots of rides and friendly staff. There is no need to worry about not being able to communicate because of poor English. Most signs will be in two languages. The security measures are also very good...."
#
#    Confidence: 0.705 | Stars: 5
#    Review: "A must visit place if you have come to Singapore. Negative points may be that it require one whole day and it is costly (80 Singapore dollars) but its worth to spend time and money on it...."
#
#    Confidence: 0.697 | Stars: 5
#    Review: "A must visit place if you are coming to Singapore if you bring your children because it is a resort island that provides various activities for yourself or your family. Usually this place is filled with visitors from overseas and local tourists. You must book your tickets earlier online and come earlier to enter the theme park...."
#
#    Confidence: 0.695 | Stars: 5
#    Review: "I've been here twice, a place that is one of the destinations for foreign tourists when visiting Singapore..."
#
#    Confidence: 0.693 | Stars: 5
#    Review: "Places that must be visited when on holiday in Singapore...."
#
#    Confidence: 0.687 | Stars: 5
#    Review: "Best attraction to visit more than once in a life time. Expecting some more food counters and indian food options in menu. Without Universal Studios your journey in Singapore is worthless. I prefer to start your way opposite to enjoy all rides...."
#
#    Confidence: 0.686 | Stars: 5
#    Review: "must visit place with family and friends when in singapore..."
#
#
# BUDGET_CONSCIOUS (Top 8 high confidence):
#    Confidence: 0.697 | Stars: 4
#    Review: "Overrated only rides and high cost. Also, need proper display of info on cost and other things...."
#
#    Confidence: 0.693 | Stars: 2
#    Review: "Completely overpriced, not enough to see for the high entrance fee. Some systems were not in operation. Too long waiting time. A show was simply canceled. There are better attractions in Singapore...."
#
#    Confidence: 0.690 | Stars: 1
#    Review: "For the Transformers project, I queued for an hour and then the facility broke down and I had to go out to play other projects. The park only apologized verbally but did not compensate tourists for their sunk time cost! For the other three roller coasters, you have to rent lockers to store all your belongings before you can ride them. The price is ..."
#
#    Confidence: 0.688 | Stars: 1
#    Review: "We paid a ticket to spend all whole day and it was so crowded that we use just 4 attractions. We went to spend our last day in singapore and it was disappointed. Quality and price do not seem to go togheter......"
#
#    Confidence: 0.683 | Stars: 5
#    Review: "While everything is so expensive here, you get a decent experience riding the attractions. Long queue may happen in some of the parks most anticipated attractions like battlestar galactica and lost worlds. Before arriving at the park, make sure youve planned what attractions you wanted the most since its almost impossible to ride all the attraction..."
#
#    Confidence: 0.682 | Stars: 5
#    Review: "A fun place to spend money, filled with many rides that can make you spend money without realizing it because it makes your adrenaline and emotions torn apart by temporary hallucinations that will produce feelings of regret when it all ends. A place that makes a large contribution to Singapore's tax income so it has abundant finances. By coming her..."
#
#    Confidence: 0.679 | Stars: 5
#    Review: "Singapore's highlights and landmarks, lots of tourists .. Food is quite expensive here..."
#
#    Confidence: 0.679 | Stars: 3
#    Review: "The amusement park is pretty and some of the decorations are well done. Various Shows are offered (see start times) Despite this I find the park quickly small and very expensive!! If you are in Singapore for a few days, it is not worth spending money there...."
#
#
# PREMIUM_VISITORS (Top 8 high confidence):
#    Confidence: 0.695 | Stars: 4
#    Review: "There are three types of Express Passes: 1. Express Pass One-time access to each ride (excludes Minion Land) 2. Express Plus Pass One-time access to each ride including Minion Land 3. VIP Experience Unlimited access, VIP line, and a guided tour (approx. 4x the cost of a regular ticket) Express Passes can cost up to SGD 1,000 more than standard tick..."
#
#    Confidence: 0.690 | Stars: 4
#    Review: "Vip Express ticket's help us for best experience. Otherwise you have to stay in the long queue & With children's that is not good at all...."
#
#    Confidence: 0.689 | Stars: 5
#    Review: "Suggest buying express access in advance..."
#
#    Confidence: 0.688 | Stars: 5
#    Review: "Must visit place if you are in Singapore. It's worth to take "Express" as an add-on while booking ticket...."
#
#    Confidence: 0.688 | Stars: 2
#    Review: "Express pass is a "Rip Off". Food is advertised colourfully but disaster when it is served. Cutlery, bowls, plates all in plastic. Bloody expensive. They need to learn from the Americans on how to do certain things...."
#
#    Confidence: 0.687 | Stars: 5
#    Review: "This is the best thing to go in singapore... if u want to go to every rides, u must buy express ticket along with the entry ticket.. but u can skip express ticket by doing main rides..."
#
#    Confidence: 0.685 | Stars: 5
#    Review: "One of the best and must visit place in Singapore. Better to buy express pass for fast check in...."
#
#    Confidence: 0.685 | Stars: 5
#    Review: "Went on weekend and got the unlimited express pass from the counter. It was totally worth it as the longest time I waited in queue was max around 15 mins only. Tips: - if express pass not available online on your preferred date, you can purchase from guest services at USS - bring your own water bottle and hand fan to stay hydrated and cool (singapo..."
#
#
# EXPERIENCE_FOCUSED (Top 8 high confidence):
#    Confidence: 0.762 | Stars: 1
#    Review: "Its a theme park and yeah its always busy and crowded. So the long wait for each ride is understandable. But what makes the situation worse are the staff. 1. They never smile. If I give a dollar for each staff that I see smile, I would never finish 10 for the entire day. 2. They act like police officers. I have seen a number of staff scolding visit..."
#
#    Confidence: 0.753 | Stars: 3
#    Review: "Ques were not aligned with posted durations, (all were / 25% from posted times). Minimal food vending sitrs, available ones were overwhelmed by number of guests Food quality was low, based on Singapore high standards Rides quality was low compared to other parks (US & EU) Personnel was burdened by amount of guests' relative to available support Be ..."
#
#    Confidence: 0.744 | Stars: 3
#    Review: "Long queue times even on weekdays. Some attractions will be closed, Especially when it rains, it pours in Singapore lots of renovations and expansion ongoing hopefully itll be better in the next 3 years. I queued for Transformer ride only to be informed the ride is malfunctioning. Great staff though..."
#
#    Confidence: 0.744 | Stars: 1
#    Review: "Some rides closed. Longer waiting time ( an hour) compared to pre covid. Frequent long breakdown like the mummies ride even with Express pass. Even restaurant has to queue for an hour or two. Better feed urself first before entering especially with kid and nowadays cannot enjoy light food on the street because must mask on. USJ experience was much ..."
#
#    Confidence: 0.737 | Stars: 3
#    Review: "Generally enjoy the rides and facilities. Suggest more care to monitor long queue situation where there are inconsiderate visitors who get one person to queue for family members/friends (the case we encountered was 14 members, no handicapped, he claimed and insisted that he has someone who was on the queue behind the 20 visitors...) ... eventually ..."
#
#    Confidence: 0.732 | Stars: 3
#    Review: "Typical theme park experience. Some really fun attractions tempered by long waits and dumb rules. With limited operating hours of only 11:00-18:00 outside of peak season, you're at a steep disadvantage in terms of being able to enjoy very many attractions unless you buy the express pass. You cannot conceivably ride even half of the rides without th..."
#
#    Confidence: 0.731 | Stars: 2
#    Review: "Attractions such as roller coasters often stopped operating, and there were several times when we were left waiting without adequate explanation. It took about 40 minutes at most, but I had to wait in line for that long. There are many attractions where you have to leave your luggage in a locker, but if you go longer than 45 minutes you have to pay..."
#
#    Confidence: 0.731 | Stars: 3
#    Review: "Universal Studios Singapore has some truly enjoyable attractions, and I did have fun thanks to the Express Pass I purchased. But its difficult to overlook the lack of organization and indifference shown by staff during our visit, especially at the very start of the day. Upon arriving at the park entrance, I witnessed a frustrating incident in the E..."

# %%
# Phase 4: Cosine similarity calculation and classification

print("Computing persona similarities and classifications...")
print("=" * 50)

# Convert persona embeddings to numpy array for efficient computation
persona_names = list(persona_embeddings.keys())
persona_matrix = np.array([persona_embeddings[name] for name in persona_names])

print(f"Persona matrix shape: {persona_matrix.shape}")
print(f"Review matrix shape: {review_embeddings.shape}")

# Calculate cosine similarities between all reviews and all personas
print("\nCalculating cosine similarities...")
start_time = time.time()

# Use sklearn's efficient cosine similarity
similarity_matrix = cosine_similarity(review_embeddings, persona_matrix)

end_time = time.time()
print(f"Similarity calculation completed in {end_time - start_time:.2f} seconds")
print(f"Similarity matrix shape: {similarity_matrix.shape}")

# Classify each review to the most similar persona
print("\nClassifying reviews...")

# Get the persona with highest similarity for each review
best_persona_indices = np.argmax(similarity_matrix, axis=1)
best_similarities = np.max(similarity_matrix, axis=1)

# Create detailed classification results with ALL similarities
classification_results = []
for i, (persona_idx, similarity) in enumerate(zip(best_persona_indices, best_similarities)):
    all_similarities = dict(zip(persona_names, similarity_matrix[i]))
    
    # Calculate confidence gap (difference between top 2 scores)
    sorted_similarities = sorted(similarity_matrix[i], reverse=True)
    confidence_gap = sorted_similarities[0] - sorted_similarities[1] if len(sorted_similarities) > 1 else 0
    
    # Find secondary persona
    secondary_idx = np.argsort(similarity_matrix[i])[-2]  # Second highest
    secondary_persona = persona_names[secondary_idx]
    secondary_confidence = similarity_matrix[i][secondary_idx]
    
    classification_results.append({
        'review_index': i,
        'best_persona': persona_names[persona_idx],
        'confidence': similarity,
        'secondary_persona': secondary_persona,
        'secondary_confidence': secondary_confidence,
        'confidence_gap': confidence_gap,
        'all_similarities': all_similarities
    })

print(f"Classified {len(classification_results):,} reviews")

# Quick statistics
print(f"\nClassification confidence statistics:")
print(f"Mean confidence: {np.mean(best_similarities):.3f}")
print(f"Median confidence: {np.median(best_similarities):.3f}")
print(f"Min confidence: {np.min(best_similarities):.3f}")
print(f"Max confidence: {np.max(best_similarities):.3f}")

# Confidence gap statistics
confidence_gaps = [result['confidence_gap'] for result in classification_results]
print(f"\nConfidence gap statistics:")
print(f"Mean gap: {np.mean(confidence_gaps):.3f}")
print(f"Median gap: {np.median(confidence_gaps):.3f}")
print(f"Min gap: {np.min(confidence_gaps):.3f}")
print(f"Max gap: {np.max(confidence_gaps):.3f}")
# Out:
# Computing persona similarities and classifications...
# ==================================================
# Persona matrix shape: (6, 1024)
# Review matrix shape: (24021, 1024)
#
# Calculating cosine similarities...
# Similarity calculation completed in 0.12 seconds
# Similarity matrix shape: (24021, 6)
#
# Classifying reviews...
# Classified 24,021 reviews
#
# Classification confidence statistics:
# Mean confidence: 0.543
# Median confidence: 0.550
# Min confidence: 0.302
# Max confidence: 0.762
#
# Confidence gap statistics:
# Mean gap: 0.034
# Median gap: 0.025
# Min gap: 0.000
# Max gap: 0.215

# %%
# Phase 5: Enhanced classification results analysis

print("\nClassification Distribution Analysis")
print("=" * 50)

# Add classification results to dataframe
df_classified = df.copy()
df_classified['predicted_persona'] = [result['best_persona'] for result in classification_results]
df_classified['confidence'] = [result['confidence'] for result in classification_results]
df_classified['secondary_persona'] = [result['secondary_persona'] for result in classification_results]
df_classified['secondary_confidence'] = [result['secondary_confidence'] for result in classification_results]
df_classified['confidence_gap'] = [result['confidence_gap'] for result in classification_results]

# Add all similarity scores as separate columns
for persona in persona_names:
    df_classified[f'{persona}_similarity'] = [result['all_similarities'][persona] for result in classification_results]

# 1. Overall distribution
print("1. PERSONA DISTRIBUTION:")
persona_counts = df_classified['predicted_persona'].value_counts()
persona_percentages = (persona_counts / len(df_classified) * 100).round(1)

for persona in persona_names:
    count = persona_counts.get(persona, 0)
    pct = persona_percentages.get(persona, 0)
    print(f"   {persona:20}: {count:5,} reviews ({pct:5.1f}%)")

# 2. Confidence distribution by persona
print(f"\n2. CONFIDENCE BY PERSONA:")
for persona in persona_names:
    persona_data = df_classified[df_classified['predicted_persona'] == persona]
    if len(persona_data) > 0:
        mean_conf = persona_data['confidence'].mean()
        std_conf = persona_data['confidence'].std()
        mean_gap = persona_data['confidence_gap'].mean()
        print(f"   {persona:20}: {mean_conf:.3f} ± {std_conf:.3f} (gap: {mean_gap:.3f})")

# 3. Star rating correlation
print(f"\n3. PERSONA vs STAR RATING:")
persona_star_crosstab = pd.crosstab(df_classified['predicted_persona'], df_classified['stars'], normalize='index') * 100
print(persona_star_crosstab.round(1))

# 4. NEW: Mixed personas analysis (small confidence gaps)
print(f"\n4. MIXED PERSONA PATTERNS:")
print("Top persona combinations with small confidence gaps (<0.05):")
mixed_reviews = df_classified[df_classified['confidence_gap'] < 0.05]
if len(mixed_reviews) > 0:
    mixed_combinations = mixed_reviews.groupby(['predicted_persona', 'secondary_persona']).size().sort_values(ascending=False)
    for (primary, secondary), count in mixed_combinations.head(10).items():
        pct = count / len(df_classified) * 100
        print(f"   {primary} + {secondary}: {count} reviews ({pct:.1f}%)")
else:
    print("   No reviews with confidence gap < 0.05")

# 5. NEW: Uncertain classifications
print(f"\n5. UNCERTAIN CLASSIFICATIONS:")
uncertain_threshold = 0.1
uncertain_reviews = df_classified[df_classified['confidence_gap'] < uncertain_threshold]
print(f"Reviews with confidence gap < {uncertain_threshold}: {len(uncertain_reviews)} ({len(uncertain_reviews)/len(df_classified)*100:.1f}%)")

if len(uncertain_reviews) > 0:
    print("\nTop uncertain classification examples:")
    uncertain_samples = uncertain_reviews.nsmallest(5, 'confidence_gap')
    for idx, row in uncertain_samples.iterrows():
        print(f"   Gap: {row['confidence_gap']:.3f} | {row['predicted_persona']} ({row['confidence']:.3f}) vs {row['secondary_persona']} ({row['secondary_confidence']:.3f})")
        print(f"   Review: \"{row['review'][:100]}...\"")
        print()

# 6. High confidence samples (top 3 per persona)
print(f"\n6. HIGH CONFIDENCE SAMPLES:")
print("=" * 60)

for persona in persona_names:
    persona_data = df_classified[df_classified['predicted_persona'] == persona]
    if len(persona_data) > 0:
        top_samples = persona_data.nlargest(8, 'confidence')
        print(f"\n{persona.upper()} (Top 8 high confidence):")
        for idx, row in top_samples.iterrows():
            print(f"   Confidence: {row['confidence']:.3f} | Gap: {row['confidence_gap']:.3f} | Stars: {row['stars']}")
            print(f"   Secondary: {row['secondary_persona']} ({row['secondary_confidence']:.3f})")
            print(f"   Review: \"{row['review'][:200]}...\"")
            print()


print(f"\n8. SAVE ENHANCED RESULTS:")

processed_path = project_root / 'data' / 'processed'

processed_path.mkdir(parents=True, exist_ok=True)

csv_file = 'USS_Reviews_Silver_cleaned_l3.csv'
parquet_file = 'USS_Reviews_Silver_cleaned_l3.parquet'

csv_path = processed_path / csv_file
parquet_path = processed_path / parquet_file

# save as csv
print(f"Saving CSV to: {csv_path}")
df_classified.to_csv(csv_path, index=False)
print(f"✓ Enhanced classification results saved to '{csv_path}'")

# save as parquet
print(f"Saving Parquet to: {parquet_path}")
df_classified.to_parquet(parquet_path, index=False)
print(f"✓ Enhanced classification results saved to '{parquet_path}'")

print(f"✓ Includes all {len(persona_names)} persona similarity scores for each review")
print(f"✓ Total columns: {len(df_classified.columns)}")
print(f"✓ Total rows: {len(df_classified):,}")

# compare size
import os
csv_size = os.path.getsize(csv_path) / (1024*1024)  # MB
parquet_size = os.path.getsize(parquet_path) / (1024*1024)  # MB

print(f"\nFile size comparison:")
print(f"  CSV: {csv_size:.1f} MB")
print(f"  Parquet: {parquet_size:.1f} MB")
print(f"  Space savings: {((csv_size - parquet_size) / csv_size * 100):.1f}%")

print(f"\nNext time you can load either format:")
print(f"  df = pd.read_csv('{csv_path}')")
print(f"  df = pd.read_parquet('{parquet_path}')  # Faster loading")
# Out:
# Classification Distribution Analysis
# ==================================================
# 1. PERSONA DISTRIBUTION:
#    families            : 5,076 reviews ( 21.1%)
#    thrill_seekers      : 3,141 reviews ( 13.1%)
#    international_tourists: 3,649 reviews ( 15.2%)
#    budget_conscious    : 1,323 reviews (  5.5%)
#    premium_visitors    : 2,914 reviews ( 12.1%)
#    experience_focused  : 7,918 reviews ( 33.0%)
#
# 2. CONFIDENCE BY PERSONA:
#    families            : 0.519 ± 0.073 (gap: 0.039)
#    thrill_seekers      : 0.504 ± 0.064 (gap: 0.028)
#    international_tourists: 0.541 ± 0.070 (gap: 0.025)
#    budget_conscious    : 0.527 ± 0.074 (gap: 0.025)
#    premium_visitors    : 0.549 ± 0.076 (gap: 0.032)
#    experience_focused  : 0.575 ± 0.069 (gap: 0.039)
#
# 3. PERSONA vs STAR RATING:
# stars                      1    2     3     4     5
# predicted_persona
# budget_conscious        10.4  7.6  16.3  20.9  44.7
# experience_focused      13.5  7.9  16.2  26.2  36.2
# families                 0.4  0.5   3.9  19.7  75.6
# international_tourists   0.4  0.3   1.8  12.9  84.6
# premium_visitors         2.1  0.8   5.2  19.3  72.6
# thrill_seekers           0.2  0.4   2.3  14.9  82.3
#
# 4. MIXED PERSONA PATTERNS:
# Top persona combinations with small confidence gaps (<0.05):
#    experience_focused + premium_visitors: 1422 reviews (5.9%)
#    experience_focused + budget_conscious: 1242 reviews (5.2%)
#    premium_visitors + experience_focused: 1072 reviews (4.5%)
#    experience_focused + families: 1029 reviews (4.3%)
#    families + experience_focused: 1007 reviews (4.2%)
#    families + international_tourists: 1003 reviews (4.2%)
#    experience_focused + thrill_seekers: 866 reviews (3.6%)
#    international_tourists + families: 848 reviews (3.5%)
#    experience_focused + international_tourists: 834 reviews (3.5%)
#    thrill_seekers + experience_focused: 773 reviews (3.2%)
#
# 5. UNCERTAIN CLASSIFICATIONS:
# Reviews with confidence gap < 0.1: 22994 (95.7%)
#
# Top uncertain classification examples:
#    Gap: 0.000 | premium_visitors (0.347) vs experience_focused (0.347)
#    Review: "It doesn't even come in... it's just on the page..."
#
#    Gap: 0.000 | budget_conscious (0.397) vs thrill_seekers (0.397)
#    Review: "Must try the turkey thigh which is as big as a poskamling bat..."
#
#    Gap: 0.000 | premium_visitors (0.515) vs families (0.515)
#    Review: "Have visited over 15 times in the last 7 years and yes makes me take friends each time I have one . ..."
#
#    Gap: 0.000 | experience_focused (0.455) vs thrill_seekers (0.455)
#    Review: "I cannot explain how mesmerising and beautiful it is! The big palace, crazy theme, amazing rides mak..."
#
#    Gap: 0.000 | families (0.390) vs premium_visitors (0.390)
#    Review: "You can finish it in one day..."
#
#
# 6. HIGH CONFIDENCE SAMPLES:
# ============================================================
#
# FAMILIES (Top 8 high confidence):
#    Confidence: 0.723 | Gap: 0.118 | Stars: 5
#    Secondary: international_tourists (0.605)
#    Review: "Good travel with small and big kids. There are zone for teenagers and younger kids.Most importantly, they have few cozy places for adults to spend their free times with friends.eg casio and cinema and..."
#
#    Confidence: 0.714 | Gap: 0.081 | Stars: 5
#    Secondary: international_tourists (0.633)
#    Review: "It was an amazing experience with family there. One of the best places to be visited in Singapore. The minimum age for kids to ride is 4 but few rides allow them based on their height too. Kids above ..."
#
#    Confidence: 0.708 | Gap: 0.048 | Stars: 5
#    Secondary: international_tourists (0.659)
#    Review: "I really like going here, the place is very INSTAGRAMable.. The kids are really happy, especially the parents.. haha it's really a kid's heaven.. I bought the entrance ticket at Traveloka, so when I g..."
#
#    Confidence: 0.694 | Gap: 0.049 | Stars: 4
#    Secondary: international_tourists (0.645)
#    Review: "Travel with family to Singapore..."
#
#    Confidence: 0.693 | Gap: 0.013 | Stars: 3
#    Secondary: budget_conscious (0.679)
#    Review: "Very much aimed at young children, with very little for Adults, the exception being Cyclone. Tickets arent cheap but are inline with Singapore expectations. The Express (Fast Pass) tickets are worthwh..."
#
#    Confidence: 0.692 | Gap: 0.164 | Stars: 5
#    Secondary: international_tourists (0.528)
#    Review: "A child-friendly place and suitable for traveling with family. highly recommended..."
#
#    Confidence: 0.691 | Gap: 0.026 | Stars: 5
#    Secondary: international_tourists (0.665)
#    Review: "It's amazing when i still child. With family 14 people go to singapore. We not get to inside Universal but we took around sentosa island. It's great place 4 days in singapore and i'm really happy. Bad..."
#
#    Confidence: 0.691 | Gap: 0.090 | Stars: 5
#    Secondary: international_tourists (0.601)
#    Review: "A very pleasant place to visit in Singapore. Apart from theme parks, there are actually other options to visit, including aquariums and museums, which can be an option for parents who bring children a..."
#
#
# THRILL_SEEKERS (Top 8 high confidence):
#    Confidence: 0.704 | Gap: 0.026 | Stars: 5
#    Secondary: premium_visitors (0.679)
#    Review: "One of the top spots in Singapore, highly crowded because of its popularity, is highly recommended for adrenaline junkies. Suggestion: Spend a Lil more to save time because of the long queues, buy an ..."
#
#    Confidence: 0.704 | Gap: 0.202 | Stars: 5
#    Secondary: budget_conscious (0.502)
#    Review: "Adrenalin rush riding the extreme rides...."
#
#    Confidence: 0.701 | Gap: 0.103 | Stars: 5
#    Secondary: international_tourists (0.598)
#    Review: "The best place to get your adrenaline spiked. The rides are amazing and thrilling. The staff is very polite and also so many souvenirs to get. If you visit Singapore, you have to visit here Love Love ..."
#
#    Confidence: 0.697 | Gap: 0.122 | Stars: 5
#    Secondary: international_tourists (0.575)
#    Review: "One of the few places for adrenaline seekers in SG..."
#
#    Confidence: 0.695 | Gap: 0.049 | Stars: 4
#    Secondary: premium_visitors (0.646)
#    Review: "The most popular theme park in south east asia I guess. They divided the park with about 5 main theme. Attractions are really interesting and great. They even tell the instructions with 2 language (En..."
#
#    Confidence: 0.680 | Gap: 0.124 | Stars: 5
#    Secondary: experience_focused (0.556)
#    Review: "Roller coaster ride. You need lot of courage and inner strength to face gravity forces in roller coaster guide. Clean toilets available...."
#
#    Confidence: 0.675 | Gap: 0.069 | Stars: 5
#    Secondary: international_tourists (0.606)
#    Review: "Universal Studios Singapore is a world class theme park. They have various rides and attractions, each with distinct themes. They have many options for non-adrenaline riders as well. Will be looking f..."
#
#    Confidence: 0.669 | Gap: 0.060 | Stars: 5
#    Secondary: international_tourists (0.608)
#    Review: "Must visit place for the adventure seekers in singapore. There are 5-6 rides will definitely gives you chills and adrenaline rush. Transformer, The Mummy, Battelstar Gallecia Cycon & Human, Jurrasic w..."
#
#
# INTERNATIONAL_TOURISTS (Top 8 high confidence):
#    Confidence: 0.721 | Gap: 0.113 | Stars: 5
#    Secondary: families (0.608)
#    Review: "1st timer in Singapore should include on their itenerary...."
#
#    Confidence: 0.717 | Gap: 0.052 | Stars: 5
#    Secondary: families (0.665)
#    Review: "The first time I went to Singapore was to come here. I was pleasantly surprised. It was much better than I expected. I am a tourist from Malaysia. Lots of rides and friendly staff. There is no need to..."
#
#    Confidence: 0.705 | Gap: 0.020 | Stars: 5
#    Secondary: budget_conscious (0.686)
#    Review: "A must visit place if you have come to Singapore. Negative points may be that it require one whole day and it is costly (80 Singapore dollars) but its worth to spend time and money on it...."
#
#    Confidence: 0.697 | Gap: 0.033 | Stars: 5
#    Secondary: families (0.663)
#    Review: "A must visit place if you are coming to Singapore if you bring your children because it is a resort island that provides various activities for yourself or your family. Usually this place is filled wi..."
#
#    Confidence: 0.695 | Gap: 0.129 | Stars: 5
#    Secondary: budget_conscious (0.566)
#    Review: "I've been here twice, a place that is one of the destinations for foreign tourists when visiting Singapore..."
#
#    Confidence: 0.693 | Gap: 0.112 | Stars: 5
#    Secondary: families (0.582)
#    Review: "Places that must be visited when on holiday in Singapore...."
#
#    Confidence: 0.687 | Gap: 0.050 | Stars: 5
#    Secondary: premium_visitors (0.637)
#    Review: "Best attraction to visit more than once in a life time. Expecting some more food counters and indian food options in menu. Without Universal Studios your journey in Singapore is worthless. I prefer to..."
#
#    Confidence: 0.686 | Gap: 0.051 | Stars: 5
#    Secondary: families (0.635)
#    Review: "must visit place with family and friends when in singapore..."
#
#
# BUDGET_CONSCIOUS (Top 8 high confidence):
#    Confidence: 0.697 | Gap: 0.079 | Stars: 4
#    Secondary: experience_focused (0.618)
#    Review: "Overrated only rides and high cost. Also, need proper display of info on cost and other things...."
#
#    Confidence: 0.693 | Gap: 0.068 | Stars: 2
#    Secondary: experience_focused (0.625)
#    Review: "Completely overpriced, not enough to see for the high entrance fee. Some systems were not in operation. Too long waiting time. A show was simply canceled. There are better attractions in Singapore...."
#
#    Confidence: 0.690 | Gap: 0.015 | Stars: 1
#    Secondary: experience_focused (0.675)
#    Review: "For the Transformers project, I queued for an hour and then the facility broke down and I had to go out to play other projects. The park only apologized verbally but did not compensate tourists for th..."
#
#    Confidence: 0.688 | Gap: 0.023 | Stars: 1
#    Secondary: experience_focused (0.665)
#    Review: "We paid a ticket to spend all whole day and it was so crowded that we use just 4 attractions. We went to spend our last day in singapore and it was disappointed. Quality and price do not seem to go to..."
#
#    Confidence: 0.683 | Gap: 0.002 | Stars: 5
#    Secondary: international_tourists (0.681)
#    Review: "While everything is so expensive here, you get a decent experience riding the attractions. Long queue may happen in some of the parks most anticipated attractions like battlestar galactica and lost wo..."
#
#    Confidence: 0.682 | Gap: 0.045 | Stars: 5
#    Secondary: international_tourists (0.637)
#    Review: "A fun place to spend money, filled with many rides that can make you spend money without realizing it because it makes your adrenaline and emotions torn apart by temporary hallucinations that will pro..."
#
#    Confidence: 0.679 | Gap: 0.028 | Stars: 5
#    Secondary: international_tourists (0.651)
#    Review: "Singapore's highlights and landmarks, lots of tourists .. Food is quite expensive here..."
#
#    Confidence: 0.679 | Gap: 0.045 | Stars: 3
#    Secondary: experience_focused (0.634)
#    Review: "The amusement park is pretty and some of the decorations are well done. Various Shows are offered (see start times) Despite this I find the park quickly small and very expensive!! If you are in Singap..."
#
#
# PREMIUM_VISITORS (Top 8 high confidence):
#    Confidence: 0.695 | Gap: 0.117 | Stars: 4
#    Secondary: budget_conscious (0.578)
#    Review: "There are three types of Express Passes: 1. Express Pass One-time access to each ride (excludes Minion Land) 2. Express Plus Pass One-time access to each ride including Minion Land 3. VIP Experience U..."
#
#    Confidence: 0.690 | Gap: 0.031 | Stars: 4
#    Secondary: experience_focused (0.658)
#    Review: "Vip Express ticket's help us for best experience. Otherwise you have to stay in the long queue & With children's that is not good at all...."
#
#    Confidence: 0.689 | Gap: 0.197 | Stars: 5
#    Secondary: experience_focused (0.492)
#    Review: "Suggest buying express access in advance..."
#
#    Confidence: 0.688 | Gap: 0.024 | Stars: 5
#    Secondary: international_tourists (0.664)
#    Review: "Must visit place if you are in Singapore. It's worth to take "Express" as an add-on while booking ticket...."
#
#    Confidence: 0.688 | Gap: 0.014 | Stars: 2
#    Secondary: budget_conscious (0.674)
#    Review: "Express pass is a "Rip Off". Food is advertised colourfully but disaster when it is served. Cutlery, bowls, plates all in plastic. Bloody expensive. They need to learn from the Americans on how to do ..."
#
#    Confidence: 0.687 | Gap: 0.034 | Stars: 5
#    Secondary: international_tourists (0.653)
#    Review: "This is the best thing to go in singapore... if u want to go to every rides, u must buy express ticket along with the entry ticket.. but u can skip express ticket by doing main rides..."
#
#    Confidence: 0.685 | Gap: 0.036 | Stars: 5
#    Secondary: international_tourists (0.649)
#    Review: "One of the best and must visit place in Singapore. Better to buy express pass for fast check in...."
#
#    Confidence: 0.685 | Gap: 0.078 | Stars: 5
#    Secondary: experience_focused (0.607)
#    Review: "Went on weekend and got the unlimited express pass from the counter. It was totally worth it as the longest time I waited in queue was max around 15 mins only. Tips: - if express pass not available on..."
#
#
# EXPERIENCE_FOCUSED (Top 8 high confidence):
#    Confidence: 0.762 | Gap: 0.104 | Stars: 1
#    Secondary: budget_conscious (0.658)
#    Review: "Its a theme park and yeah its always busy and crowded. So the long wait for each ride is understandable. But what makes the situation worse are the staff. 1. They never smile. If I give a dollar for e..."
#
#    Confidence: 0.753 | Gap: 0.090 | Stars: 3
#    Secondary: budget_conscious (0.663)
#    Review: "Ques were not aligned with posted durations, (all were / 25% from posted times). Minimal food vending sitrs, available ones were overwhelmed by number of guests Food quality was low, based on Singapor..."
#
#    Confidence: 0.744 | Gap: 0.109 | Stars: 3
#    Secondary: international_tourists (0.636)
#    Review: "Long queue times even on weekdays. Some attractions will be closed, Especially when it rains, it pours in Singapore lots of renovations and expansion ongoing hopefully itll be better in the next 3 yea..."
#
#    Confidence: 0.744 | Gap: 0.092 | Stars: 1
#    Secondary: international_tourists (0.651)
#    Review: "Some rides closed. Longer waiting time ( an hour) compared to pre covid. Frequent long breakdown like the mummies ride even with Express pass. Even restaurant has to queue for an hour or two. Better f..."
#
#    Confidence: 0.737 | Gap: 0.116 | Stars: 3
#    Secondary: premium_visitors (0.621)
#    Review: "Generally enjoy the rides and facilities. Suggest more care to monitor long queue situation where there are inconsiderate visitors who get one person to queue for family members/friends (the case we e..."
#
#    Confidence: 0.732 | Gap: 0.078 | Stars: 3
#    Secondary: budget_conscious (0.655)
#    Review: "Typical theme park experience. Some really fun attractions tempered by long waits and dumb rules. With limited operating hours of only 11:00-18:00 outside of peak season, you're at a steep disadvantag..."
#
#    Confidence: 0.731 | Gap: 0.075 | Stars: 2
#    Secondary: international_tourists (0.657)
#    Review: "Attractions such as roller coasters often stopped operating, and there were several times when we were left waiting without adequate explanation. It took about 40 minutes at most, but I had to wait in..."
#
#    Confidence: 0.731 | Gap: 0.047 | Stars: 3
#    Secondary: premium_visitors (0.684)
#    Review: "Universal Studios Singapore has some truly enjoyable attractions, and I did have fun thanks to the Express Pass I purchased. But its difficult to overlook the lack of organization and indifference sho..."
#
#
# 8. SAVE ENHANCED RESULTS:
# Saving CSV to: C:\Users\nshan\Desktop\SMU\MITB\CS605\project\CS605-NLP-Project\data\processed\USS_Reviews_Silver_cleaned_l3.csv
# ✓ Enhanced classification results saved to 'C:\Users\nshan\Desktop\SMU\MITB\CS605\project\CS605-NLP-Project\data\processed\USS_Reviews_Silver_cleaned_l3.csv'
# Saving Parquet to: C:\Users\nshan\Desktop\SMU\MITB\CS605\project\CS605-NLP-Project\data\processed\USS_Reviews_Silver_cleaned_l3.parquet
# ✓ Enhanced classification results saved to 'C:\Users\nshan\Desktop\SMU\MITB\CS605\project\CS605-NLP-Project\data\processed\USS_Reviews_Silver_cleaned_l3.parquet'
# ✓ Includes all 6 persona similarity scores for each review
# ✓ Total columns: 18
# ✓ Total rows: 24,021
#
# File size comparison:
#   CSV: 13.1 MB
#   Parquet: 7.0 MB
#   Space savings: 46.4%
#
# Next time you can load either format:
#   df = pd.read_csv('C:\Users\nshan\Desktop\SMU\MITB\CS605\project\CS605-NLP-Project\data\processed\USS_Reviews_Silver_cleaned_l3.csv')
#   df = pd.read_parquet('C:\Users\nshan\Desktop\SMU\MITB\CS605\project\CS605-NLP-Project\data\processed\USS_Reviews_Silver_cleaned_l3.parquet')  # Faster loading
